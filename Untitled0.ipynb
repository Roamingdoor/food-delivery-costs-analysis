# %%
import pandas as pd
df = pd.read_csv("food delivery costs.csv")
df
# Out:
#      Order ID Customer ID Restaurant ID  Order Date and Time  \
# 0           1       C8270         R2924   2024-02-01 1:11:52
# 1           2       C1860         R2054  2024-02-02 22:11:04
# 2           3       C6390         R2870   2024-01-31 5:54:35
# 3           4       C6191         R2642  2024-01-16 22:52:49
# 4           5       C6734         R2799   2024-01-29 1:19:30
# ..        ...         ...           ...                  ...
# 995       996       C6232         R2129   2024-01-14 5:57:00
# 996       997       C6797         R2742   2024-01-28 8:50:43
# 997       998       C5926         R2837   2024-01-21 9:43:19
# 998       999       C7016         R2144  2024-01-30 22:23:38
# 999      1000       C4335         R2890  2024-01-08 14:46:43
#
#     Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0       2024-02-01 2:39:52         1914             0       Credit Card
# 1      2024-02-02 22:46:04          986            40    Digital Wallet
# 2       2024-01-31 6:52:35          937            30  Cash on Delivery
# 3      2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4       2024-01-29 2:48:30         1992            30  Cash on Delivery
# ..                     ...          ...           ...               ...
# 995     2024-01-14 6:39:00          825             0    Digital Wallet
# 996    2024-01-28 10:10:43         1627            50  Cash on Delivery
# 997    2024-01-21 10:44:19          553            20  Cash on Delivery
# 998     2024-01-31 0:07:38         1414             0  Cash on Delivery
# 999    2024-01-08 15:39:43         1657            20    Digital Wallet
#
#     Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0              5% on App             150                      47
# 1                    10%             198                      23
# 2           15% New User             195                      45
# 3                    NaN             146                      27
# 4           50 off Promo             130                      50
# ..                   ...             ...                     ...
# 995            5% on App             165                      47
# 996                  NaN             110                      42
# 997                  NaN              64                      31
# 998         15% New User             199                      34
# 999         15% New User             180                      27
#
#      Refunds/Chargebacks
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 995                   50
# 996                    0
# 997                    0
# 998                    0
# 999                  100
#
# [1000 rows x 12 columns]

# %%
df.head()
# Out:
#    Order ID Customer ID Restaurant ID  Order Date and Time  \
# 0         1       C8270         R2924   2024-02-01 1:11:52
# 1         2       C1860         R2054  2024-02-02 22:11:04
# 2         3       C6390         R2870   2024-01-31 5:54:35
# 3         4       C6191         R2642  2024-01-16 22:52:49
# 4         5       C6734         R2799   2024-01-29 1:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0     2024-02-01 2:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2     2024-01-31 6:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4     2024-01-29 2:48:30         1992            30  Cash on Delivery
#
#   Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0            5% on App             150                      47
# 1                  10%             198                      23
# 2         15% New User             195                      45
# 3                  NaN             146                      27
# 4         50 off Promo             130                      50
#
#    Refunds/Chargebacks
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1000 non-null   int64
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   object
#  4   Delivery Date and Time  1000 non-null   object
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 93.9+ KB

# %% [markdown]
# # **cleaning of data**

# %%
df["Order Date and Time"] = pd.to_datetime(df["Order Date and Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1000 non-null   int64
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   datetime64[ns]
#  4   Delivery Date and Time  1000 non-null   object
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
df["Delivery Date and Time"] = pd.to_datetime(df["Delivery Date and Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1000 non-null   int64
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   datetime64[ns]
#  4   Delivery Date and Time  1000 non-null   datetime64[ns]
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: datetime64[ns](2), int64(6), object(4)
# memory usage: 93.9+ KB

# %%
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#   Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0            5% on App             150                      47
# 1                  10%             198                      23
# 2         15% New User             195                      45
# 3                  NaN             146                      27
# 4         50 off Promo             130                      50
#
#    Refunds/Chargebacks
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
def extract(value):
  a = str(value).split(" ")
  return a[0]

df["Discounts and Offers"] = df["Discounts and Offers"].apply(extract)
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#   Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0                   5%             150                      47
# 1                  10%             198                      23
# 2                  15%             195                      45
# 3                  nan             146                      27
# 4                   50             130                      50
#
#    Refunds/Chargebacks
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
def removep(value):
  if isinstance(value, str) and "%" in value:
      a = value.replace("%","")
      return float(a)
  elif isinstance(value, str):
      return float(value)
  else:
      return value

df["Discounts and Offers"] = df["Discounts and Offers"].apply(removep)
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#    Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0             33.333333             150                      47
# 1             66.666667             198                      23
# 2            100.000000             195                      45
# 3              0.000000             146                      27
# 4             50.000000             130                      50
#
#    Refunds/Chargebacks       Costs     Profit
# 0                    0   80.333333  69.666667
# 1                    0  129.666667  68.333333
# 2                    0  175.000000  20.000000
# 3                    0   77.000000  69.000000
# 4                    0  130.000000   0.000000

# %%
df.loc[(df["Discounts and Offers"] <= 15),"Discounts and Offers" ] = (df["Discounts and Offers"]/100) * df["Order Value"]
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#    Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0             33.333333             150                      47
# 1             66.666667             198                      23
# 2            100.000000             195                      45
# 3              0.000000             146                      27
# 4             50.000000             130                      50
#
#    Refunds/Chargebacks       Costs     Profit
# 0                    0   80.333333  69.666667
# 1                    0  129.666667  68.333333
# 2                    0  175.000000  20.000000
# 3                    0   77.000000  69.000000
# 4                    0  130.000000   0.000000

# %%
df["Discounts and Offers"] = df["Discounts and Offers"].fillna(0)
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#    Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0             33.333333             150                      47
# 1             66.666667             198                      23
# 2            100.000000             195                      45
# 3              0.000000             146                      27
# 4             50.000000             130                      50
#
#    Refunds/Chargebacks
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df["Costs"] = df["Delivery Fee"] + df["Discounts and Offers"] + df["Payment Processing Fee"]
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#    Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0             33.333333             150                      47
# 1             66.666667             198                      23
# 2            100.000000             195                      45
# 3              0.000000             146                      27
# 4             50.000000             130                      50
#
#    Refunds/Chargebacks       Costs
# 0                    0   80.333333
# 1                    0  129.666667
# 2                    0  175.000000
# 3                    0   77.000000
# 4                    0  130.000000

# %%
df["Profit"] = df["Commission Fee"] - df["Costs"]
df.head()
# Out:
#    Order ID Customer ID Restaurant ID Order Date and Time  \
# 0         1       C8270         R2924 2024-02-01 01:11:52
# 1         2       C1860         R2054 2024-02-02 22:11:04
# 2         3       C6390         R2870 2024-01-31 05:54:35
# 3         4       C6191         R2642 2024-01-16 22:52:49
# 4         5       C6734         R2799 2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#    Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0             33.333333             150                      47
# 1             66.666667             198                      23
# 2            100.000000             195                      45
# 3              0.000000             146                      27
# 4             50.000000             130                      50
#
#    Refunds/Chargebacks       Costs     Profit
# 0                    0   80.333333  69.666667
# 1                    0  129.666667  68.333333
# 2                    0  175.000000  20.000000
# 3                    0   77.000000  69.000000
# 4                    0  130.000000   0.000000

# %%
df["Profit"].sum()
# Out:
# 17054.66666666666

# %%
cost_distribution = df[["Delivery Fee", "Payment Processing Fee", "Discounts and Offers"]].sum()
cost_distribution
# Out:
# Delivery Fee              28620.000000
# Payment Processing Fee    29832.000000
# Discounts and Offers      51483.333333
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))
plt.pie(cost_distribution, labels = cost_distribution.index, autopct="%1.2f%%")
plt.title("Cost Distribution")
plt.show()

# %%
abc = df[["Commission Fee", "Costs", "Profit"]].sum()
abc
# Out:
# Commission Fee    126990.000000
# Costs             109935.333333
# Profit             17054.666667
# dtype: float64

# %%
plt.figure(figsize = (3,3))
plt.bar(abc.index, abc)
plt.xticks(rotation = 45)
plt.yticks(rotation = 45)
plt.show()

# %%
plt.hist(df["Profit"])
plt.show()
